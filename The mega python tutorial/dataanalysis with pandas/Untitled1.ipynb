# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'try.py',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
import pandas

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'try.py',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
df4
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df4.drop("Country",1)
# Out:
#             Address           City  Employees         Name             State
# ID
# 1      3666 21st St  San Francisco          8      Madeira          CA 94114
# 2    735 Dolores St  San Francisco         15  Bready Shop          CA 94119
# 3       332 Hill St  San Francisco         25  Super River  California 94114
# 4      3995 23rd St  San Francisco         10   Ben's Shop          CA 94114
# 5   1056 Sanchez St  San Francisco         12      Sanchez        California
# 6   551 Alvarado St  San Francisco         20   Richvalley          CA 94114

# %%
df4
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df4.drop("735 Dolores St",0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-928b4fe3b745> in <module>()
# ----> 1 df4.drop("735 Dolores St",0)
#
# c:\users\vinir_000\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\users\vinir_000\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
df4 = df4.set_index("Adress")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\vinir_000\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adress'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-454efccffeda> in <module>()
# ...

# %%
df4 = df4.set_index("Address")

# %%
df4
# Out:
#                           City Country  Employees         Name  \
# Address
# 3666 21st St     San Francisco     USA          8      Madeira
# 735 Dolores St   San Francisco     USA         15  Bready Shop
# 332 Hill St      San Francisco     USA         25  Super River
# 3995 23rd St     San Francisco     USA         10   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12      Sanchez
# 551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df4.drop("332 Hill St",0)
# Out:
#                           City Country  Employees         Name       State
# Address
# 3666 21st St     San Francisco     USA          8      Madeira    CA 94114
# 735 Dolores St   San Francisco     USA         15  Bready Shop    CA 94119
# 3995 23rd St     San Francisco     USA         10   Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12      Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   Richvalley    CA 94114

# %%
df4.drop(,1)
# Out:
#   File "<ipython-input-53-a38abd96762f>", line 1
#     df4.drop(1:2,1)
#               ^
# SyntaxError: invalid syntax

# %%
df4
# Out:
#                           City Country  Employees         Name  \
# Address
# 3666 21st St     San Francisco     USA          8      Madeira
# 735 Dolores St   San Francisco     USA         15  Bready Shop
# 332 Hill St      San Francisco     USA         25  Super River
# 3995 23rd St     San Francisco     USA         10   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12      Sanchez
# 551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
type(df4.columns[0:4])
# Out:
# pandas.core.indexes.base.Index

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
 df3.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Supermarket Name',
#        'Number of Employees'],
#       dtype='object')

# %%
df3.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-6d264c8b501c> in <module>()
# ----> 1 df3.rows
#
# c:\users\vinir_000\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3 = df3.set_index("ID")

# %%
df3
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df3.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
df3.shape
# Out:
# (6, 6)

# %%
df3.shape[0]*["india"]
# Out:
# ['india', 'india', 'india', 'india', 'india', 'india']

# %%
df3["continent"] = df3.shape[0]*["india"]

# %%
df3
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees continent
# ID
# 1                     8     india
# 2                    15     india
# 3                    25     india
# 4                    10     india
# 5                    12     india
# 6                    20     india

# %%
df3
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees continent
# ID
# 1                     8     india
# 2                    15     india
# 3                    25     india
# 4                    10     india
# 5                    12     india
# 6                    20     india

# %%
df3.T
# Out:
# ID                               1               2                 3  \
# Address               3666 21st St  735 Dolores St       332 Hill St
# City                 San Francisco   San Francisco     San Francisco
# State                     CA 94114        CA 94119  California 94114
# Country                        USA             USA               USA
# Supermarket Name           Madeira     Bready Shop       Super River
# Number of Employees              8              15                25
# continent                    india           india             india
#
# ID                               4                5                6
# Address               3995 23rd St  1056 Sanchez St  551 Alvarado St
# City                 San Francisco    San Francisco    San Francisco
# State                     CA 94114       California         CA 94114
# Country                        USA              USA              USA
# Supermarket Name        Ben's Shop          Sanchez       Richvalley
# ...

# %%
df3x = df3.T

# %%
df3x[1] = df3x.shape[0]*["Hi man"]

# %%
df3x
# Out:
# ID                        1               2                 3              4  \
# Address              Hi man  735 Dolores St       332 Hill St   3995 23rd St
# City                 Hi man   San Francisco     San Francisco  San Francisco
# State                Hi man        CA 94119  California 94114       CA 94114
# Country              Hi man             USA               USA            USA
# Supermarket Name     Hi man     Bready Shop       Super River     Ben's Shop
# Number of Employees  Hi man              15                25             10
# continent            Hi man           india             india          india
#
# ID                                 5                6       7
# Address              1056 Sanchez St  551 Alvarado St  Hi man
# City                   San Francisco    San Francisco  Hi man
# State                     California         CA 94114  Hi man
# Country                          USA              USA  Hi man
# ...

# %%
df3 = df3x.T

# %%
df3
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1            Hi man         Hi man            Hi man  Hi man           Hi man
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
# 7            Hi man         Hi man            Hi man  Hi man           Hi man
#
#    Number of Employees continent
# ID
# 1               Hi man    Hi man
# 2                   15     india
# 3                   25     india
# 4                   10     india
# 5                   12     india
# 6                   20     india
# 7               Hi man    Hi man
